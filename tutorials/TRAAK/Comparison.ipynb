# %%
import ctgomartini.topology as topology

# %%
import os
os.getcwd()
from pathlib import Path
working_dir = Path(os.getcwd())

# %%
top = topology.TopologyParser(working_dir/'worked'/'Up'/'system.top')

# %%
mol = top.moleculeTypes['Up']

# %%
top.forcefield.__dict__['nonbond_params'][('Up_1', 'Up_5')]
# Out:
# ['Up_5', 'Up_1', '1', '0.55165679', '12.00000000']
